# %% [markdown]
# <a href="https://colab.research.google.com/github/Gangadhar24377/VQGAN-training-model_Images/blob/main/Copy_of_VqGan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/RohitMidha23/Image-Directory-to-CSV
# Out:
# fatal: destination path 'Image-Directory-to-CSV' already exists and is not an empty directory.

# %% [markdown]
# Converting the dataset into .csv file as the input is file

# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

# default format can be changed as needed
def createFileList(myDir, formats=['.jpg', '.jpeg', '.png']):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            for format in formats:
                if name.endswith(format):
                    fullName = os.path.join(root, name)
                    fileList.append(fullName)
    return fileList

# load the original image
myFileList = createFileList('/content/Images')

for file in myFileList:
    try:
        print(file)
        img_file = Image.open(file)
        # img_file.show()

        # get original image parameters...
        width, height = img_file.size
        format = img_file.format
        mode = img_file.mode

        # Make image Greyscale
        img_grey = img_file.convert('L')
        #img_grey.save('result.png')
        #img_grey.show()

        # Save Greyscale values
        value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
        value = value.flatten()
        print(value)
        with open("/content/dataset.csv", 'a') as f:
            writer = csv.writer(f)
            writer.writerow(value)
    except OSError as e:
        print(f"Error: {e}")
# Out:
# /content/Images
# /content/Images/1 (15).png
# [238 238 238 ... 105 103 105]
# <ipython-input-2-260fc523d5ce>:39: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
# /content/Images/1 (33).jpg
# [147 147 147 ...  36  36  36]
# /content/Images/1 (17).png
# [107 107 109 ...  97  96  96]
# /content/Images/1 (55).jpeg
# [176 176 176 ... 163 162 163]
# /content/Images/1 (14).jpg
# [222 222 222 ...   6   6   7]
# /content/Images/1 (99).jpg
# [24 24 25 ... 27 27 27]
# /content/Images/1 (70).jpg
# [218 219 220 ... 215 217 217]
# /content/Images/1 (17).jpeg
# [197 197 197 ... 189 189 190]
# /content/Images/1 (54).png
# [105 105 105 ... 255 255 255]
# /content/Images/1 (79).jpeg
# [ 86  85  81 ... 172 172 172]
# /content/Images/1 (12).png
# [52 52 52 ... 52 52 52]
# /content/Images/1 (72).png
# [68 70 71 ... 67 65 66]
# /content/Images/1 (85).jpg
# [ 92  90  87 ... 185 183 185]
# /content/Images/1 (25).jpg
# [ 7  8 10 ... 28 28 28]
# /content/Images/1 (57).jpeg
# [193 193 194 ... 115 113 111]
# /content/Images/1 (23).png
# [126 124 122 ... 178 178 178]
# /content/Images/1 (50).png
# [126 124 122 ... 178 178 178]
# /content/Images/1 (17).jpg
# [205 205 205 ...  44  42  42]
# /content/Images/1 (31).png
# [225 225 225 ...  99  99  99]
# /content/Images/1 (3).png
# [161 161 160 ...  90  87  82]
# /content/Images/1 (38).png
# [255 255 255 ... 255 255 255]
# /content/Images/1 (46).jpeg
# [190 190 190 ... 182 182 181]
# /content/Images/1 (71).jpeg
# [176 176 176 ... 163 162 163]
# /content/Images/1 (79).jpg
# [229 227 231 ... 244 241 242]
# /content/Images/1 (26).jpg
# [212 212 211 ... 245 245 245]
# /content/Images/1 (82).jpg
# [11  4  9 ...  1  1  1]
# [32 30 32 ...  1  1  1]
# /content/Images/1 (36).jpg
# [178 177 176 ... 203 200 201]
# /content/Images/1 (44).jpg
# [187 187 186 ... 255 255 255]
# /content/Images/1 (13).png
# [ 69  66  73 ... 141 144 136]
# /content/Images/1 (45).jpeg
# [  2   0   3 ... 247 246 246]
# /content/Images/1 (40).jpeg
# [87 88 89 ...  4  4  4]
# /content/Images/1 (27).jpeg
# [208 209 210 ...   7   6  10]
# /content/Images/1 (34).png
# [238 238 238 ... 105 103 105]
# /content/Images/1 (2).jpeg
# [156 156 156 ... 153 149 146]
# /content/Images/1 (77).jpg
# [108 107 105 ...  64  64  66]
# /content/Images/1 (42).jpg
# [255 250 255 ... 248 255 255]
# /content/Images/1 (44).jpeg
# [193 193 194 ... 115 113 111]
# /content/Images/1 (69).jpeg
# [249 249 249 ...  16  16  14]
# /content/Images/1 (60).jpg
# [255 255 255 ... 255 255 255]
# /content/Images/1 (62).jpeg
# [87 88 89 ...  4  4  4]
# /content/Images/1 (12).jpg
# [ 91  91  91 ... 124 123 121]
# /content/Images/1 (61).jpeg
# [208 209 210 ...   7   6  10]
# /content/Images/1 (71).jpg
# [11 11 11 ... 50 50 51]
# /content/Images/1 (37).png
# [238 238 238 ... 105 103 105]
# /content/Images/1 (58).jpeg
# [24 24 24 ... 19 19 20]
# /content/Images/1 (7).jpeg
# [ 0  0  0 ... 14 13 13]
# /content/Images/1 (5).jpg
# [255 255 255 ... 193 194 194]
# /content/Images/1 (95).jpg
# [8 6 5 ... 3 6 6]
# /content/Images/1 (79).png
# [223 238 234 ... 255 255 255]
# /content/Images/1 (6).png
# [245 245 245 ...  59  54  56]
# /content/Images/1 (67).jpeg
# [106 105 104 ...  13  11   9]
# /content/Images/1 (35).jpg
# [ 61  62  67 ... 188 187 190]
# /content/Images/1 (34).jpeg
# [191 191 191 ... 145 145 145]
# /content/Images/1 (1).jpg
# [210 210 210 ... 183 183 183]
# /content/Images/1 (64).jpg
# [ 2  2  2 ... 92 88 85]
# /content/Images/1 (66).jpg
# [45 46 47 ... 12 23 29]
# /content/Images/1 (56).jpeg
# [  2   0   3 ... 247 246 246]
# /content/Images/1 (57).jpg
# [230 231 232 ... 172 181 177]
# /content/Images/1 (62).png
# [41 41 41 ...  3  4  2]
# /content/Images/1 (15).jpg
# [33 33 33 ... 23 23 23]
# /content/Images/1 (37).jpeg
# [103 103 103 ...  13  11  10]
# /content/Images/1 (80).png
# [245 245 245 ...  20  21  26]
# /content/Images/1 (61).jpg
# [139 140 140 ...  12  13  13]
# /content/Images/1 (65).jpg
# [84 84 84 ... 20 18 18]
# /content/Images/1 (1).png
# [105 105 105 ... 255 255 255]
# /content/Images/1 (60).png
# [  0   0   0 ... 105 104 107]
# /content/Images/1 (67).png
# [  0   0   0 ... 140 135   0]
# /content/Images/1 (54).jpg
# [151 151 151 ... 250 250 250]
# /content/Images/1 (49).jpeg
# [24 24 24 ... 19 19 20]
# /content/Images/1 (30).jpg
# [143 143 144 ... 201 201 201]
# /content/Images/1 (96).png
# [255 255 255 ... 255 255 255]
# /content/Images/1 (61).png
# [ 9  9 10 ...  8  8  8]
# /content/Images/1 (59).jpeg
# [190 190 190 ... 182 182 181]
# /content/Images/1 (41).jpeg
# [176 176 176 ... 163 162 163]
# /content/Images/1 (11).png
# [52 52 52 ... 52 52 52]
# /content/Images/1 (85).png
# [243 243 243 ... 251 251 251]
# /content/Images/1 (49).jpg
# [163 162 161 ...  52  51  50]
# /content/Images/1 (95).png
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /content/Images/1 (46).png
# [52 52 52 ... 52 52 52]
# /content/Images/1 (93).png
# [222 222 222 ... 232 233 233]
# /content/Images/1 (93).jpg
# [43 43 43 ... 33 24 22]
# /content/Images/1 (70).jpeg
# [191 191 191 ... 145 145 145]
# /content/Images/1 (23).jpg
# [46 46 46 ... 46 46 45]
# /content/Images/1 (74).png
# [37 36 36 ... 32 32 31]
# /content/Images/1 (100).jpg
# [255 255 255 ... 196 196 196]
# /content/Images/1 (50).jpeg
# [69 74 79 ... 41 32 42]
# /content/Images/1 (73).jpg
# [ 85  86  87 ... 116 118 121]
# /content/Images/1 (48).jpeg
# [208 209 210 ...   7   6  10]
# /content/Images/1 (39).jpg
# [187 187 187 ... 220 220 220]
# /content/Images/1 (35).png
# [161 161 160 ...  90  87  82]
# /content/Images/1 (70).png
# [102 101 103 ...  47  46  45]

# %%
# !pip install git+https://github.com/patil-suraj/vqgan-jax.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/patil-suraj/vqgan-jax.git
#   Cloning https://github.com/patil-suraj/vqgan-jax.git to /tmp/pip-req-build-6jdfteea
#   Running command git clone --filter=blob:none --quiet https://github.com/patil-suraj/vqgan-jax.git /tmp/pip-req-build-6jdfteea
#   Resolved https://github.com/patil-suraj/vqgan-jax.git to commit 10ef240f8ace869e437f3c32d14898f61512db12
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jax>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from vqgan-jax==0.0.1) (0.4.6)
# Requirement already satisfied: flax in /usr/local/lib/python3.9/dist-packages (from vqgan-jax==0.0.1) (0.6.7)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (from vqgan-jax==0.0.1) (4.27.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from jax>=0.2.6->vqgan-jax==0.0.1) (1.22.4)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.9/dist-packages (from jax>=0.2.6->vqgan-jax==0.0.1) (1.10.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax>=0.2.6->vqgan-jax==0.0.1) (3.3.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (6.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (1.0.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (0.1.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (4.5.0)
# Requirement already satisfied: orbax in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (0.1.5)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (13.3.2)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.9/dist-packages (from flax->vqgan-jax==0.0.1) (0.1.33)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (3.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (2.27.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers->vqgan-jax==0.0.1) (0.13.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=11.1->flax->vqgan-jax==0.0.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=11.1->flax->vqgan-jax==0.0.1) (2.14.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.9/dist-packages (from optax->flax->vqgan-jax==0.0.1) (0.4.6+cuda11.cudnn86)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from optax->flax->vqgan-jax==0.0.1) (1.4.0)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.9/dist-packages (from optax->flax->vqgan-jax==0.0.1) (0.1.6)
# Requirement already satisfied: cached_property in /usr/local/lib/python3.9/dist-packages (from orbax->flax->vqgan-jax==0.0.1) (1.5.2)
# Requirement already satisfied: etils in /usr/local/lib/python3.9/dist-packages (from orbax->flax->vqgan-jax==0.0.1) (1.1.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.9/dist-packages (from orbax->flax->vqgan-jax==0.0.1) (5.12.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.9/dist-packages (from orbax->flax->vqgan-jax==0.0.1) (1.5.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->vqgan-jax==0.0.1) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->vqgan-jax==0.0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->vqgan-jax==0.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers->vqgan-jax==0.0.1) (2022.12.7)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.9/dist-packages (from chex>=0.1.5->optax->flax->vqgan-jax==0.0.1) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from chex>=0.1.5->optax->flax->vqgan-jax==0.0.1) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1->flax->vqgan-jax==0.0.1) (0.1.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib_resources->orbax->flax->vqgan-jax==0.0.1) (3.15.0)

# %%
# VQGAN-JAX - pmap encoding HowTo

import numpy as np

# For data loading
import torch
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets.folder import default_loader
from torchvision.transforms import InterpolationMode

# For data saving
from pathlib import Path
import pandas as pd
from tqdm import tqdm

import jax
from jax import pmap

from vqgan_jax.modeling_flax_vqgan import VQModel
# Out:
# /usr/local/lib/python3.9/dist-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(

# %%
## Params and arguments

# List of paths containing images to encode
image_list = '/sddata/dalle-mini/CC12M/10k.tsv'
output_tsv = 'output.tsv'                # Encoded results
batch_size = 64
num_workers = 4    # TPU v3-8s have 96 cores, so feel free to increase this number when necessary

# Load model

model = VQModel.from_pretrained("flax-community/vqgan_f16_16384", ignore_mismatched_sizes=True)
# Out:
# WARNING:jax._src.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Some weights of VQModel were not initialized from the model checkpoint at flax-community/vqgan_f16_16384 and are newly initialized because the shapes did not match:
# - ('decoder', 'mid', 'attn_1', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'attn_1', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'mid', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'norm_out', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'norm_out', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_0', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_1', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_1', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_1', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('decoder', 'up_2', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_2', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_3', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_3', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_3', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('decoder', 'up_4', 'attn_0', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'attn_0', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'attn_1', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'attn_1', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'attn_2', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'attn_2', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('decoder', 'up_4', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_0', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_0', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_1', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_2', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_2', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 128) in the checkpoint and (128,) in the model instantiated
# - ('encoder', 'down_2', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_2', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_2', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_2', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_2', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_2', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_3', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_4', 'attn_0', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'attn_0', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'attn_1', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'attn_1', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_0', 'norm1', 'bias'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_4', 'block_0', 'norm1', 'scale'): found shape (1, 1, 1, 256) in the checkpoint and (256,) in the model instantiated
# - ('encoder', 'down_4', 'block_0', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_0', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'down_4', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'attn_1', 'norm', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'attn_1', 'norm', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_1', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_1', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_1', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_1', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_2', 'norm1', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_2', 'norm1', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_2', 'norm2', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'mid', 'block_2', 'norm2', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'norm_out', 'bias'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# - ('encoder', 'norm_out', 'scale'): found shape (1, 1, 1, 512) in the checkpoint and (512,) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
## Data Loading.

# Simple torch Dataset to load images from paths.
# You can use your own pipeline instead.
class ImageDataset(Dataset):
    def __init__(self, image_list_path: str, image_size: int, max_items=None):
        """
        :param image_list_path: Path to a file containing a list of all images. We assume absolute paths for now.
        :param image_size: Image size. Source images will be resized and center-cropped.
        :max_items: Limit dataset size for debugging
        """
        
        self.image_list = pd.read_csv(image_list_path, sep='\t', header=None)
        if max_items is not None: self.image_list = self.image_list[:max_items]
        self.image_size = image_size
        
        
    def __len__(self):
        return len(self.image_list)
    
    def _get_raw_image(self, i):
        image_path = Path(self.image_list.iloc[i][0])
        return default_loader(image_path)
    
    def resize_image(self, image):
        s = min(image.size)
        r = self.image_size / s
        s = (round(r * image.size[1]), round(r * image.size[0]))
        image = TF.resize(image, s, interpolation=InterpolationMode.LANCZOS)
        image = TF.center_crop(image, output_size = 2 * [self.image_size])
        image = np.expand_dims(np.array(image), axis=0)
        return image
    
    def __getitem__(self, i):
        image = self._get_raw_image(i)
        return self.resize_image(image)

# %%
## Encoding

# Encoding function to be parallelized with `pmap`
# Note: images have to be square
def encode(model, batch):
    _, indices = model.encode(batch)
    return indices

# %%
# Alternative: create a batch with num_tpus*batch_size and use `shard` to distribute.
def superbatch_generator(dataloader, num_tpus):
    iter_loader = iter(dataloader)
    for batch in iter_loader:
        superbatch = [batch.squeeze(1)]
        try:
            for _ in range(num_tpus-1):
                batch = next(iter_loader)
                if batch is None:
                    break
                # Skip incomplete last batch
                if batch.shape[0] == dataloader.batch_size:
                    superbatch.append(batch.squeeze(1))
        except StopIteration:
            pass
        superbatch = torch.stack(superbatch, axis=0)
        yield superbatch

def encode_dataset(dataset, batch_size=32):
    dataloader = DataLoader(dataset, batch_size=batch_size, num_workers=num_workers)
    superbatches = superbatch_generator(dataloader, num_tpus=jax.device_count())
    
    num_tpus = jax.device_count()
    dataloader = DataLoader(dataset, batch_size=batch_size, num_workers=num_workers)
    superbatches = superbatch_generator(dataloader, num_tpus=num_tpus)
    
    p_encoder = pmap(lambda batch: encode(model, batch))

    # Save each superbatch to avoid reallocation of buffers as we process them.
    # Keep the file open to prevent excessive file seeks.
    with open(output_tsv, "w") as file:
        iterations = len(dataset) // (batch_size * num_tpus)
        for n in tqdm(range(iterations)):
            superbatch = next(superbatches)
            encoded = p_encoder(superbatch.numpy())
            encoded = encoded.reshape(-1, encoded.shape[-1])

            # Extract paths from the dataset, save paths and encodings (as string)
            start_index = n * batch_size * num_tpus
            end_index = (n+1) * batch_size * num_tpus
            paths = dataset.image_list[start_index:end_index][0].values
            encoded_as_string = list(map(lambda item: np.array2string(item, separator=',', max_line_width=100, formatter={'int':lambda x: str(x)}), encoded))
            batch_df = pd.DataFrame.from_dict({"image_file": paths, "encoding": encoded_as_string})
            batch_df.to_csv(file, sep='\t', header=(n==0), index=None)
            
dataset = ImageDataset(image_list_path="/content/dataset.csv", image_size=256)
encoded_dataset = encode_dataset(dataset, batch_size=batch_size)
